# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import numpy as np
import json

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                City      Lat      Lng  Max Temp  Humidity  \
# 0        0   port-aux-francais -49.3500  70.2167     41.34        99
# 1        1             kashgar  39.4547  75.9797     43.81        31
# 2        2        longyearbyen  78.2186  15.6401     31.84        86
# 3        3          st. john's  47.5649 -52.7093     39.88        91
# 4        4  san jose de jachal -30.2406 -68.7469     67.75        89
#
#    Cloudiness  Wind Speed Country        Date
# 0         100       21.41      TF  1701236552
# 1          20        4.47      CN  1701236563
# 2          40        1.14      SJ  1701236564
# 3          75       11.50      CA  1701236481
# 4          76        8.70      AR  1701236566

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    'Lng',
    'Lat',
    geo = True,
    tiles = 'OSM',
    frame_width = 700,
    frame_height = 500
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_cities_df = city_data_df[(city_data_df['Max Temp'] > 75) & (city_data_df['Max Temp'] < 95) & 
                               (city_data_df['Wind Speed'] < 4.5) & (city_data_df['Cloudiness'] < 15)]
# Drop any rows with null values
clean_ideal_cities = ideal_cities_df.dropna()

# Display sample data
clean_ideal_cities
# Out:
#      City_ID             City      Lat      Lng  Max Temp  Humidity  \
# 120      120        micheweni  -4.9667  39.8333     83.03        73
# 138      138     saint-joseph -21.3667  55.6167     84.47        67
# 150      150  remire-montjoly   4.9167 -52.2667     75.24        94
# 184      184       porto novo   6.4965   2.6036     76.80        91
# 244      244     al majaridah  19.1236  41.9111     81.30        48
# 272      272           gudari  19.3500  83.7833     87.58        41
# 415      415           yanqul  23.5905  56.5501     78.24        33
#
#      Cloudiness  Wind Speed Country        Date
# 120          14        4.25      TZ  1701236868
# 138           4        1.01      RE  1701236887
# 150           0        0.00      GF  1701236901
# 184          14        3.78      BJ  1701236935
# 244           0        2.95      SA  1701236997
# 272           3        1.32      IN  1701237047
# 415           1        0.85      OM  1701237275

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = clean_ideal_cities[['City', 'Country', 'Lat', 'Lng', 'Humidity']]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
# C:\Users\Claire\AppData\Local\Temp\ipykernel_29164\3795971818.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df['Hotel Name'] = ''
#                 City Country      Lat      Lng  Humidity Hotel Name
# 120        micheweni      TZ  -4.9667  39.8333        73
# 138     saint-joseph      RE -21.3667  55.6167        67
# 150  remire-montjoly      GF   4.9167 -52.2667        94
# 184       porto novo      BJ   6.4965   2.6036        91
# 244     al majaridah      SA  19.1236  41.9111        48
# 272           gudari      IN  19.3500  83.7833        41
# 415           yanqul      OM  23.5905  56.5501        33

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
categories = 'accommodation.hotel'
radius = 10000
params = {
    'categories': categories,
    'apiKey': geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row['Lat']
    lon = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f'circle:{lon},{lat},{radius}'
    params["bias"] = f'proximity:{lon},{lat}'
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# micheweni - nearest hotel: No hotel found
# saint-joseph - nearest hotel: PALM Hotel & Spa
# remire-montjoly - nearest hotel: Complexe Belova
# porto novo - nearest hotel: Hôtel 6500 CFA
# al majaridah - nearest hotel: No hotel found
# gudari - nearest hotel: No hotel found
# yanqul - nearest hotel: No hotel in this town
#                 City Country      Lat      Lng  Humidity  \
# 120        micheweni      TZ  -4.9667  39.8333        73
# 138     saint-joseph      RE -21.3667  55.6167        67
# 150  remire-montjoly      GF   4.9167 -52.2667        94
# 184       porto novo      BJ   6.4965   2.6036        91
# 244     al majaridah      SA  19.1236  41.9111        48
# 272           gudari      IN  19.3500  83.7833        41
# 415           yanqul      OM  23.5905  56.5501        33
#
#                 Hotel Name
# 120         No hotel found
# 138       PALM Hotel & Spa
# 150        Complexe Belova
# 184         Hôtel 6500 CFA
# 244         No hotel found
# 272         No hotel found
# 415  No hotel in this town

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    'Lng',
    'Lat',
    geo = True,
    tiles = 'OSM',
    frame_width = 600,
    frame_height = 500,
    hover_cols=['City', 'Humidity', 'Hotel Name', 'Country'],
    color = 'City'
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
